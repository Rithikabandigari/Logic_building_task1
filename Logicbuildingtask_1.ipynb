# %% [markdown]
# 1. User Login Check
# Problem Statement:
# Given a username and password, check whether login is successful.
# username = "admin"
# password = "1234"
#
# Requirements:
# Print "Login Successful" if both username and password match
# Otherwise print "Invalid Credentials"

# %%
user = "admin"
password = "1234"
u=input("Enter Username:")
p=input("Enter Password")
if u==user and p==password:
  print("Login Successful")
else:
  print("Invalid Credentials")
# Out:
# Enter Username:admin
# Enter Password1234
# Login Successful

# %% [markdown]
# 2. Pass / Fail Analyzer
# Problem Statement:
# Analyze student results.
# marks = [45, 78, 90, 33, 60]
#
# Requirements:
# A student passes if marks ≥ 50
# Count the total number of pass students
# Count the total number of fail students
# Print the final result clearly

# %%
marks=[45,78,90,33,60]
passcount=0
failcount=0
for i in (marks):
  if i>50 or i==50:
    passcount+=1
  elif  i<50:
    failcount+=1
print(" Total number of students Passed: ",passcount)
print(" Total number of students failed: ",failcount)
# Out:
#  Total number of students Passed:  3
#  Total number of students failed:  2

# %% [markdown]
# 3. Simple Data Cleaner
# Problem Statement:
# Clean and standardize user names.
# names = [" Alice ", "bob", " CHARLIE "]
#
# Requirements:
# Remove extra spaces
# Convert all names to lowercase
# Print the cleaned list

# %%
names=[" Alice ", "bob", " CHARLIE "]
new_list=[]
for name in names:
  cleaned_name=name.strip().lower()
  new_list.append(cleaned_name)
print(new_list)
# Out:
# ['alice', 'bob', 'charlie']

# %% [markdown]
# 4. Message Length Analyzer
# Problem Statement:
# Analyze message sizes.
# messages = ["Hi", "Welcome to the platform", "OK"]
#
# Requirements:
# Print the length of each message
# Flag messages longer than 10 characters
# Real-World Application: Text filtering and validation systems

# %%
messages = ["Hi", "Welcome to the platform", "OK"]
length=[]
for msg in messages:
  length=len(msg)
  print("Message:",msg)
  print("Length:",length)
  if length>10:
    print("message Size Longer Than 10 !!!")
  elif length<=10:
    print("Message size Less Than 10 ")
# Out:
# Message: Hi
# Length: 2
# Message size Less Than 10
# Message: Welcome to the platform
# Length: 23
# message Size Longer Than 10 !!!
# Message: OK
# Length: 2
# Message size Less Than 10

# %% [markdown]
# 5. Error Message Detector
# Problem Statement:
# Detect error messages from system logs.
# logs = ["INFO", "ERROR", "WARNING", "ERROR"]
#
# Requirements:
# Count the number of "ERROR" entries
# Print the total error count
# Real-World Application: Monitoring and log analysis systems

# %%
logs = ["INFO", "ERROR", "WARNING", "ERROR"]
errorcount=0
for log in logs:
  if log=="ERROR":
    errorcount+=1
print("Total errors:",errorcount)
# Out:
# Total errors: 2
